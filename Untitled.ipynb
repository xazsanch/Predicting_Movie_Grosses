# %%
import tmdbsimple as tmdb
tmdb.API_KEY = 'b8ab01d0873c83efc0847a932b724068'

# %%
movie = tmdb.Movies(603)

# %%
response = movie.info()

# %%
movie.rating()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-15-8ba159475520> in <module>
# ----> 1 movie.rating()
#
# ~/anaconda3/lib/python3.7/site-packages/tmdbsimple/movies.py in rating(self, **kwargs)
#     360         }
#     361
# --> 362         response = self._POST(path, kwargs, payload)
#     363         self._set_attrs_to_values(response)
#     364         return response
#
# ~/anaconda3/lib/python3.7/site-packages/tmdbsimple/base.py in _POST(self, path, params, payload)
#     110
#     111     def _POST(self, path, params=None, payload=None):
# --> 112         return self._request('POST', path, params=params, payload=payload)
#     113
#     114     def _DELETE(self, path, params=None, payload=None):
#
# ~/anaconda3/lib/python3.7/site-packages/tmdbsimple/base.py in _request(self, method, path, params, payload)
#     102             )
#     103
# ...

# %%
movie.top_rated()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg',
#    'genre_ids': [10749, 35],
#    'id': 761053,
#    'original_language': 'en',
#    'original_title': "Gabriel's Inferno Part III",
#    'overview': "The final part of the film adaption of the erotic romance novel Gabriel's Inferno written by an anonymous Canadian author under the pen name Sylvain Reynard.",
#    'popularity': 34.87,
#    'poster_path': '/fYtHxTxlhzD4QWfEbrC1rypysSD.jpg',
#    'release_date': '2020-11-19',
#    'title': "Gabriel's Inferno Part III",
#    'video': False,
#    'vote_average': 8.8,
#    'vote_count': 751},
#   {'adult': False,
#    'backdrop_path': '/jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg',
#    'genre_ids': [10749],
#    'id': 724089,
#    'original_language': 'en',
#    'original_title': "Gabriel's Inferno Part II",
# ...
